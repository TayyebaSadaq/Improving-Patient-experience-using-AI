# %% [markdown]
# # AI Solutions for intelligent vehicles:

# %% [markdown]
# Importing the dataset needed for the project:
# * need to go throuhg the dataset and see what needs importing

# %%
import pandas as pd

# Load the dataset 
dataset_labels = # same for all sets??? (to check)
settings_left = # same for all sets??? (to check)
settings_right = # same for all sets??? (to check)

PVS1_gps = "/kaggle/input/pvs-passive-vehicular-sensors-datasets/PVS 1/dataset_gps.csv"
PVS1_gps_left = "/kaggle/input/pvs-passive-vehicular-sensors-datasets/PVS 1/dataset_gps_mpu_left.csv" 
PVS1_gps_right = "/kaggle/input/pvs-passive-vehicular-sensors-datasets/PVS 1/dataset_gps_mpu_right.csv"
PVS1_mpu_left = "/kaggle/input/pvs-passive-vehicular-sensors-datasets/PVS 1/dataset_mpu_left.csv"
PVS1_mpu_right = "/kaggle/input/pvs-passive-vehicular-sensors-datasets/PVS 1/dataset_mpu_right.csv"

PVS2_gps = ""
PVS2_gps_left = ""
PVS2_gps_right = ""
PVS2_mpu_left = ""
PVS2_mpu_right = ""

PVS3_gps = ""
PVS3_gps_left = ""
PVS3_gps_right = ""
PVS3_mpu_left = ""
PVS3_mpu_right = ""

PVS4_gps = ""
PVS4_gps_left = ""
PVS4_gps_right = ""
PVS4_mpu_left = ""
PVS4_mpu_right = ""

PVS5_gps = ""
PVS5_gps_left = ""
PVS5_gps_right = ""
PVS5_mpu_left = ""
PVS5_mpu_right = ""

PVS6_gps = ""
PVS6_gps_left = ""
PVS6_gps_right = ""
PVS6_mpu_left = ""
PVS6_mpu_right = ""

PVS7_gps = "" 
PVS7_gps_left = ""
PVS7_gps_right = ""
PVS7_mpu_left = ""
PVS7_mpu_right = ""

PVS8_gps = ""
PVS8_gps_left = ""
PVS8_gps_right = ""
PVS8_mpu_left = ""
PVS8_mpu_right = ""

PVS9_gps = ""
PVS9_gps_left = ""
PVS9_gps_right = ""
PVS9_mpu_left = ""
PVS9_mpu_right = ""
